# %% [markdown]
# # 01. openai api key 테스트

# %%
import os
from dotenv import load_dotenv
# load_dotenv(override=True, dotenv_path="../.env")

# %% [markdown]
# - os.getenv("OPENAI_API_KEY")

# %% [markdown]
# - os.environ["OPENAI_API_KEY"]
